# %% [markdown]
# # Import Libraries and Data

# %%
import os

# %%
import pandas as pd

# %%
pwd = os.getcwd()

# %%
filepath = pwd + '/KPMG_VI_New_raw_data_update_final_Edited.xlsx'
filepath

# %% [markdown]
# # Transactions Data

# %% [markdown]
# ### Data Exploration

# %%
trans = pd.read_excel(filepath, sheet_name='Transactions')
trans
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                   1           2         2950       2017-02-25           0.0
# 1                   2           3         3120       2017-05-21           1.0
# 2                   3          37          402       2017-10-16           0.0
# 3                   4          88         3135       2017-08-31           0.0
# 4                   5          78          787       2017-10-01           1.0
# ...               ...         ...          ...              ...           ...
# 19995           19996          51         1018       2017-06-24           1.0
# 19996           19997          41          127       2017-11-09           1.0
# 19997           19998          87         2284       2017-04-14           1.0
# 19998           19999           6         2764       2017-07-03           0.0
# 19999           20000          11         1144       2017-09-22           1.0
#
# ...

# %%
trans.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# ...

# %%
trans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  datetime64[ns]
#  4   online_order             19640 non-null  float64
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            19803 non-null  float64
#  12  product_first_sold_date  19803 non-null  float64
# ...

# %%
trans['product_first_sold_date'] = pd.to_datetime(trans['product_first_sold_date']).dt.date 
trans.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost product_first_sold_date
# ...

# %%
trans.shape
# Out:
# (20000, 13)

# %%
trans.describe()
# Out:
#        transaction_id   product_id   customer_id  online_order    list_price  \
# count    20000.000000  20000.00000  20000.000000  19640.000000  20000.000000
# mean     10000.500000     45.36465   1738.246050      0.500458   1107.829449
# std       5773.647028     30.75359   1011.951046      0.500013    582.825242
# min          1.000000      0.00000      1.000000      0.000000     12.010000
# 25%       5000.750000     18.00000    857.750000      0.000000    575.270000
# 50%      10000.500000     44.00000   1736.000000      1.000000   1163.890000
# 75%      15000.250000     72.00000   2613.000000      1.000000   1635.300000
# max      20000.000000    100.00000   5034.000000      1.000000   2091.470000
#
#        standard_cost
# count   19803.000000
# mean      556.046951
# std       405.955660
# min         7.210000
# 25%       215.140000
# 50%       507.580000
# 75%       795.100000
# max      1759.850000

# %%
trans.isnull().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
dup = trans.duplicated()
trans[dup].sum()
# Out:
# /var/folders/zw/2d3xr1_n5znc90v9p6r8r_fc0000gn/T/ipykernel_13286/3562737044.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   trans[dup].sum()
# transaction_id             0.0
# product_id                 0.0
# customer_id                0.0
# online_order               0.0
# order_status               0.0
# brand                      0.0
# product_line               0.0
# product_class              0.0
# product_size               0.0
# list_price                 0.0
# standard_cost              0.0
# product_first_sold_date    0.0
# dtype: float64

# %%
trans.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost product_first_sold_date
# ...

# %%
trans_unq_IDs = len(pd.unique(trans['customer_id']))
trans_unq_IDs
# Out:
# 3494

# %%
trans["transaction_date"].describe()
# Out:
# /var/folders/zw/2d3xr1_n5znc90v9p6r8r_fc0000gn/T/ipykernel_13286/747414515.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   trans["transaction_date"].describe()
# count                   20000
# unique                    364
# top       2017-02-14 00:00:00
# freq                       82
# first     2017-01-01 00:00:00
# last      2017-12-30 00:00:00
# Name: transaction_date, dtype: object

# %% [markdown]
# # Customer Demographics

# %%
demo = pd.read_excel(filepath, sheet_name='CustomerDemographic')
demo.head()
# Out:
# /var/folders/zw/2d3xr1_n5znc90v9p6r8r_fc0000gn/T/ipykernel_13286/4082373070.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype={value.dtype})
#   demo = pd.read_excel(filepath, sheet_name='CustomerDemographic')
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# ...

# %%
demo.shape
# Out:
# (4000, 13)

# %%
demo = demo.drop(columns=["default"])

# %%
demo.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator owns_car  tenure
# 0                Health      Mass Customer                  N      Yes    11.0
# ...

# %%
demo.describe()
# Out:
#        customer_id  past_3_years_bike_related_purchases       tenure
# count  4000.000000                          4000.000000  3913.000000
# mean   2000.500000                            48.890000    10.657041
# std    1154.844867                            28.715005     5.660146
# min       1.000000                             0.000000     1.000000
# 25%    1000.750000                            24.000000     6.000000
# 50%    2000.500000                            48.000000    11.000000
# 75%    3000.250000                            73.000000    15.000000
# max    4000.000000                            99.000000    22.000000

# %%
demo.isnull().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %%
demodups = demo.duplicated()
demo[demodups].sum()
# Out:
# /var/folders/zw/2d3xr1_n5znc90v9p6r8r_fc0000gn/T/ipykernel_13286/75224152.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   demo[demodups].sum()
# customer_id                            0.0
# first_name                             0.0
# last_name                              0.0
# gender                                 0.0
# past_3_years_bike_related_purchases    0.0
# job_title                              0.0
# job_industry_category                  0.0
# wealth_segment                         0.0
# deceased_indicator                     0.0
# owns_car                               0.0
# tenure                                 0.0
# dtype: float64

# %%
demo.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator owns_car  tenure
# 0                Health      Mass Customer                  N      Yes    11.0
# ...

# %%
demo_unq_IDs = len(pd.unique(demo['customer_id']))
demo_unq_IDs
# Out:
# 4000

# %%
demo['gender'].value_counts()
# Out:
# Female    2037
# Male      1872
# U           88
# F            1
# Femal        1
# M            1
# Name: gender, dtype: int64

# %%
demo['gender'] = demo['gender'].replace('F','Female').replace('Femal','Female').replace('M','Male')

# %%
demo['gender'].value_counts()
# Out:
# Female    2039
# Male      1873
# U           88
# Name: gender, dtype: int64

# %%
demo.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp  Female
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator owns_car  tenure
# 0                Health      Mass Customer                  N      Yes    11.0
# ...

# %%
demo['DOB'].describe()
# Out:
# /var/folders/zw/2d3xr1_n5znc90v9p6r8r_fc0000gn/T/ipykernel_13286/515012319.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   demo['DOB'].describe()
# count                    3913
# unique                   3448
# top       1978-01-30 00:00:00
# freq                        7
# first     1843-12-21 00:00:00
# last      2002-03-11 00:00:00
# Name: DOB, dtype: object

# %% [markdown]
# # Customer Address Data

# %%
add = pd.read_excel(filepath, sheet_name='CustomerAddress')
add.head()
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %%
add.shape
# Out:
# (3999, 6)

# %%
add.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         3999 non-null   int64
#  1   address             3999 non-null   object
#  2   postcode            3999 non-null   int64
#  3   state               3999 non-null   object
#  4   country             3999 non-null   object
#  5   property_valuation  3999 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 187.6+ KB

# %%
add.describe()
# Out:
#        customer_id     postcode  property_valuation
# count  3999.000000  3999.000000         3999.000000
# mean   2003.987997  2985.755939            7.514379
# std    1154.576912   844.878364            2.824663
# min       1.000000  2000.000000            1.000000
# 25%    1004.500000  2200.000000            6.000000
# 50%    2004.000000  2768.000000            8.000000
# 75%    3003.500000  3750.000000           10.000000
# max    4003.000000  4883.000000           12.000000

# %%
add_unq_IDs = len(pd.unique(add['customer_id']))
add_unq_IDs
# Out:
# 3999

# %%
add.head()
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %%
add['state'].value_counts()
# Out:
# NSW                2054
# VIC                 939
# QLD                 838
# New South Wales      86
# Victoria             82
# Name: state, dtype: int64

# %%
add['state'] = add['state'].replace('New South Wales','NSW').replace('Victoria','VIC')

# %%
add['state'].value_counts()
# Out:
# NSW    2140
# VIC    1021
# QLD     838
# Name: state, dtype: int64

# %%
add.head()
# Out:
#    customer_id              address  postcode state    country  \
# 0            1   060 Morning Avenue      2016   NSW  Australia
# 1            2  6 Meadow Vale Court      2153   NSW  Australia
# 2            4   0 Holy Cross Court      4211   QLD  Australia
# 3            5  17979 Del Mar Point      2448   NSW  Australia
# 4            6     9 Oakridge Court      3216   VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %%
trans_demo = pd.merge(trans, demo, how='inner', left_on= ['customer_id'], right_on=['customer_id'])

# %%
trans_demo.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1           11065           1         2950       2017-10-16           0.0
# 2           18923          62         2950       2017-04-26           0.0
# 3               2           3         3120       2017-05-21           1.0
# 4            6862           4         3120       2017-10-05           0.0
#
#   order_status           brand product_line product_class product_size  ...  \
# 0     Approved           Solex     Standard        medium       medium  ...
# 1     Approved  Giant Bicycles     Standard        medium       medium  ...
# 2     Approved           Solex     Standard        medium       medium  ...
# 3     Approved   Trek Bicycles     Standard        medium        large  ...
# 4     Approved  Giant Bicycles     Standard          high       medium  ...
#
# ...

# %%
list(trans_demo.columns)
# Out:
# ['transaction_id',
#  'product_id',
#  'customer_id',
#  'transaction_date',
#  'online_order',
#  'order_status',
#  'brand',
#  'product_line',
#  'product_class',
#  'product_size',
#  'list_price',
#  'standard_cost',
#  'product_first_sold_date',
#  'first_name',
#  'last_name',
#  'gender',
#  'past_3_years_bike_related_purchases',
#  'DOB',
#  'job_title',
#  'job_industry_category',
#  'wealth_segment',
#  'deceased_indicator',
#  'owns_car',
#  'tenure']

# %%
colmsdemo = ['transaction_id',
 'product_id',
 'transaction_date',
 'online_order',
 'order_status',
 'brand',
 'product_line',
 'product_class',
 'product_size',
 'list_price',
 'standard_cost',
 'product_first_sold_date']

# %%
trans_demo = trans_demo.drop(colmsdemo,axis=1)

# %%
trans_demo.head()
# Out:
#    customer_id first_name  last_name  gender  \
# 0         2950    Kristos    Anthony    Male
# 1         2950    Kristos    Anthony    Male
# 2         2950    Kristos    Anthony    Male
# 3         3120     Lauree  O'Donnell  Female
# 4         3120     Lauree  O'Donnell  Female
#
#    past_3_years_bike_related_purchases        DOB            job_title  \
# 0                                   19 1955-01-11  Software Engineer I
# 1                                   19 1955-01-11  Software Engineer I
# 2                                   19 1955-01-11  Software Engineer I
# 3                                   89 1979-02-04  Clinical Specialist
# 4                                   89 1979-02-04  Clinical Specialist
#
#   job_industry_category wealth_segment deceased_indicator owns_car  tenure
# 0    Financial Services  Mass Customer                  N      Yes    10.0
# 1    Financial Services  Mass Customer                  N      Yes    10.0
# ...

# %%
trans_add = pd.merge(trans, add, how='inner', left_on= ['customer_id'], right_on=['customer_id'])

# %%
list(trans_add.columns)
# Out:
# ['transaction_id',
#  'product_id',
#  'customer_id',
#  'transaction_date',
#  'online_order',
#  'order_status',
#  'brand',
#  'product_line',
#  'product_class',
#  'product_size',
#  'list_price',
#  'standard_cost',
#  'product_first_sold_date',
#  'address',
#  'postcode',
#  'state',
#  'country',
#  'property_valuation']

# %%
colmsadd = ['transaction_id',
 'product_id',
 'transaction_date',
 'online_order',
 'order_status',
 'brand',
 'product_line',
 'product_class',
 'product_size',
 'list_price',
 'standard_cost',
 'product_first_sold_date']

# %%
trans_add = trans_add.drop(colmsadd,axis=1)

# %%
trans_add.head()
# Out:
#    customer_id            address  postcode state    country  \
# 0         2950  984 Hoepker Court      3064   VIC  Australia
# 1         2950  984 Hoepker Court      3064   VIC  Australia
# 2         2950  984 Hoepker Court      3064   VIC  Australia
# 3         3120    4 Shopko Circle      2196   NSW  Australia
# 4         3120    4 Shopko Circle      2196   NSW  Australia
#
#    property_valuation
# 0                   6
# 1                   6
# 2                   6
# 3                   5
# 4                   5

# %%
trans_demo.to_excel(pwd+"/Demographics_Output.xlsx",index=False)
trans_add.to_excel(pwd+"/Address_Output.xlsx",index=False)
